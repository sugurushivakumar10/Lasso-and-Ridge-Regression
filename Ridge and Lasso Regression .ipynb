# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston

# %%
df= load_boston()

# %%
dataset=pd.DataFrame(df.data)

# %%
dataset.columns=df.feature_names

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
len(df.target)
# Out:
# 506

# %%
dataset.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
sns.heatmap(dataset.isnull(),cmap="viridis")

# %%
dataset["Price"]= df.target

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [raw]
# # There is correlation is so strong between "RAD", "TAX" that it can indicate a situation of multicollinearity. we
# can see in below image where the green color indicates

# %%
sns.set(font_scale=2)
plt.figure(figsize = (50,35))
ss= sns.heatmap(dataset.corr(), square = True, vmax = .8, annot = True,annot_kws={"size": 25},fmt='.1f',cmap='PiYG', linewidths=.5)
bottom, top = ss.get_ylim()
ss.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.0, 0.0)

# %%
# There is correlation is so strong between "RAD", "TAX" that it can indicate a situation of multicollinearity.

# %%
sns.jointplot(x="RAD",y="TAX", data=dataset)

# %%
plt.hist(dataset["Price"])
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
import seaborn as sns

# %%
plt.hist(dataset["AGE"])
# Out:
# (array([ 14.,  31.,  29.,  42.,  32.,  38.,  39.,  42.,  71., 168.]),
#  array([  2.9 ,  12.61,  22.32,  32.03,  41.74,  51.45,  61.16,  70.87,
#          80.58,  90.29, 100.  ]),
#  <a list of 10 Patch objects>)

# %%
sns.pairplot(dataset, vars=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE'])

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
X= dataset.iloc[:,:-1] # splitting the data whithour output varaible i'e' Price

# %%
y= dataset.iloc[:,-1] # output varaible

# %%
#from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import cross_val_score

# %%
linear_reg= LinearRegression()

# %%
mse=cross_val_score(linear_reg,X,y,scoring='neg_mean_squared_error',cv=5)

# %%
mean_mse= np.mean(mse)

# %%
mean_mse # look like mean squared error means it is near to zero
# Out:
# -37.13180746769922

# %%
linear_reg.fit(X_train,y_train) # fitting the linear model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
linear_reg.coef_
# Out:
# array([-9.85424717e-02,  6.07841138e-02,  5.91715401e-02,  2.43955988e+00,
#        -2.14699650e+01,  2.79581385e+00,  3.57459778e-03, -1.51627218e+00,
#         3.07541745e-01, -1.12800166e-02, -1.00546640e+00,  6.45018446e-03,
#        -5.68834539e-01])

# %%
coeff_dif= pd.DataFrame(linear_reg.coef_,X.columns,columns=["coefficients"]) # we can see the all coefficient X data
coeff_dif
# Out:
#          coefficients
# CRIM        -0.098542
# ZN           0.060784
# INDUS        0.059172
# CHAS         2.439560
# NOX        -21.469965
# RM           2.795814
# AGE          0.003575
# DIS         -1.516272
# RAD          0.307542
# TAX         -0.011280
# PTRATIO     -1.005466
# B            0.006450
# LSTAT       -0.568835

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge= Ridge()

# %%
# by using gridsearch cv we can findout the best parameters automatically

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}

# %%
ridge_regressor= GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
ridge_regressor.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10, 20, 30, 35, 40, 45, 50, 55, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 100}

# %%
b=ridge_regressor.best_score_
b
# Out:
# -29.87194511543252

# %%
# lasso regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
lasso= Lasso()

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso_regressor= GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
lasso_regressor.fit(X,y)
# Out:
# C:\Users\asadkhan\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\asadkhan\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\asadkhan\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
lasso_regressor.best_params_
# Out:
# {'alpha': 1}

# %%
c=lasso_regressor.best_score_
c
# Out:
# -35.49128326362709

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,random_state=1, test_size=0.3)

# %%
prediction_ridge= ridge_regressor.predict(X_test)
prediction_lasso= lasso_regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction_lasso)

# %%
sns.distplot(y_test-prediction_ridge)

# %%
sns.scatterplot(y_test,prediction_lasso)

# %%
sns.scatterplot(y_test,prediction_ridge)

# %%
plt.hist(y_test-prediction_lasso)
# Out:
# (array([12., 31., 55., 26., 10.,  7.,  2.,  3.,  4.,  2.]),
#  array([-8.19097551, -5.48457741, -2.77817932, -0.07178122,  2.63461687,
#          5.34101497,  8.04741306, 10.75381116, 13.46020925, 16.16660735,
#         18.87300544]),
#  <a list of 10 Patch objects>)
